# %%
import re
import pandas as pd 
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.support.ui import WebDriverWait
import time

# %%
driver = webdriver.Chrome()
driver.maximize_window()
url="""https://meghdadit.com/productlist/mobile/?b=115"""
driver.get(url)

# %%
t_models=[]
t_prices=[]

i = 1
while i<=2:
    driver.get(driver.current_url)
    models = driver.find_elements(By.XPATH, """/html/body/form/div[3]/div/div[3]/div/div[2]/article/div[1]/ul/li/div/div[4]/div[1]/a""")
    prices = driver.find_elements(By.XPATH, """/html/body/form/div[3]/div/div[3]/div/div[2]/article/div[1]/ul/li/div/div[4]/div[2]/div/div/span""")

    
        
    for model in models :
        name= model.text
        t_models.append(name)
    for price in prices:
        Price=price.text
        t_prices.append(Price)
    
    n_prices = [re.sub(r'[,تومان]','',price) for price in t_prices]
    
    
    next_btn =driver.find_element(By.XPATH, """/html/body/form/div[3]/div/div[3]/div/div[2]/article/div[2]/div/a[7]""")
    next_btn.click()
    i+=1

print(t_models)
print(n_prices)
# Out:
# ['گوشی موبایل شیائومی Redmi 9C رم 3GB ظرفیت 64GB دو سیم\u200c کارت', 'گوشی موبایل شیائومی مدل Mi 11 Ultra دو سیم کارت ظرفیت 256GB رم 12GB با قابلیت 5G', 'گوشی موبایل شیائومی مدل Redmi Note 11 Pro دو سیم\u200c کارت ظرفیت 128GB رم 6GB با قابلیت 5G', 'گوشی موبایل شیائومی مدل Redmi 9A دو سیم\u200c کارت ظرفیت 64 گیگابایت رم 4 گیگابایت', 'گوشی موبایل شیائومی مدل Redmi 9A دو سیم\u200c کارت ظرفیت 32 گیگابایت', 'گوشی موبایل شیائومی مدل Redmi Note 11S دو سیم\u200c کارت ظرفیت 128GB رم 8GB', 'گوشی موبایل شیائومی مدل Redmi Note 11 Pro دو سیم\u200c کارت ظرفیت 128GB رم 6GB', 'گوشی موبایل شیائومی مدل Redmi Note 11 Pro Plus 5G دو سیم\u200c کارت ظرفیت 256GB رم 8GB با قابلیت 5G', 'گوشی موبایل شیائومی مدل Redmi 10A دو سیم\u200c کارت ظرفیت 64GB رم 3GB', 'گوشی موبایل شیائومی مدل 12X دو سیم\u200c کارت ظرفیت 256 گیگابایت رم 8 گیگابایت با قابلیت 5G', 'گوشی موبایل شیائومی مدل Poco X4 Pro 5G دو سیم\u200c کارت ظرفیت 256GB رم 8GB با قابلیت 5G', 'گوشی موبایل شیائومی مدل Redmi 10C دو سیم\u200c کارت ظرفیت 64GB رم 4GB', 'گوشی موبایل شیائومی مدل Poco C40 دو سیم\u200c کارت ظرفیت 64 گیگابایت و 4 گیگابایت رم', 'گوشی موبایل شیائومی مدل Poco X5 Pro 5G دو سیم\u200c کارت ظرفیت 256GB رم 8GB با قابلیت 5G', 'گوشی موبایل شیائومی مدل Redmi Note 12 دو سیم\u200c کارت ظرفیت 128GB رم 4GB', 'گوشی موبایل شیائومی مدل Redmi Note 12 دو سیم\u200c کارت ظرفیت 128GB رم 6GB', 'گوشی موبایل شیائومی مدل Redmi Note 12 دو سیم\u200c کارت ظرفیت 128GB رم 8GB', 'گوشی موبایل شیائومی مدل Poco M5s دو سیم\u200c کارت ظرفیت 256GB رم 8GB', 'گوش
# ['4750000 ', '37900000 ', '9920000 ', '5300000 ', '3350000 ', '9200000 ', '9500000 ', '13820000 ', '4870000 ', '17600000 ', '12200000 ', '6300000 ', '4600000 ', '13250000 ', '7450000 ', '7700000 ', '7900000 ', '9200000 ', '6160000 ', '5300000 ', '9590000 ', '17500000 ', '17200000 ', '5990000 ', '7460000 ', 'جد', 'جد', 'جد', 'جد', 'جد', 'جد', 'جد', 'جد', 'جد', 'جد', 'جد', 'جد', 'جد', 'جد', 'جد', 'جد', 'جد', 'جد', 'جد', 'جد', 'جد', 'جد', 'جد']

# %%
data = {'model': t_models,'Price': n_prices}
df = pd.DataFrame(data)

# %%
df = df.drop(df[(df['Price'] == 'جد')].index)
df
# Out:
#                                                 model      Price
# 0   گوشی موبایل شیائومی Redmi 9C رم 3GB ظرفیت 64GB...   4750000
# 1   گوشی موبایل شیائومی مدل Mi 11 Ultra دو سیم کار...  37900000
# 2   گوشی موبایل شیائومی مدل Redmi Note 11 Pro دو س...   9920000
# 3   گوشی موبایل شیائومی مدل Redmi 9A دو سیم‌ کارت ...   5300000
# 4   گوشی موبایل شیائومی مدل Redmi 9A دو سیم‌ کارت ...   3350000
# 5   گوشی موبایل شیائومی مدل Redmi Note 11S دو سیم‌...   9200000
# 6   گوشی موبایل شیائومی مدل Redmi Note 11 Pro دو س...   9500000
# 7   گوشی موبایل شیائومی مدل Redmi Note 11 Pro Plus...  13820000
# 8   گوشی موبایل شیائومی مدل Redmi 10A دو سیم‌ کارت...   4870000
# 9   گوشی موبایل شیائومی مدل 12X دو سیم‌ کارت ظرفیت...  17600000
# 10  گوشی موبایل شیائومی مدل Poco X4 Pro 5G دو سیم‌...  12200000
# 11  گوشی موبایل شیائومی مدل Redmi 10C دو سیم‌ کارت...   6300000
# 12  گوشی موبایل شیائومی مدل Poco C40 دو سیم‌ کارت ...   4600000
# 13  گوشی موبایل شیائومی مدل Poco X5 Pro 5G دو سیم‌...  13250000
# 14  گوشی موبایل شیائومی مدل Redmi Note 12 دو سیم‌ ...   7450000
# 15  گوشی موبایل شیائومی مدل Redmi Note 12 دو سیم‌ ...   7700000
# 16  گوشی موبایل شیائومی مدل Redmi Note 12 دو سیم‌ ...   7900000
# 17  گوشی موبایل شیائومی مدل Poco M5s دو سیم‌ کارت ...   9200000
# 18  گوشی موبایل شیائومی مدل Redmi 12C دو سیم‌ کارت...   6160000
# 19  گوشی موبایل شیائومی مدل Redmi 12C دو سیم‌ کارت...   5300000
# 20  گوشی موبایل شیائومی مدل Redmi Note 12S دو سیم‌...   9590000
# 21  گوشی موبایل شیائومی مدل Redmi Note 12 Pro Plus...  17500000
# 22  گوشی موبایل شیائومی مدل Poco F5 دو سیم‌ کارت ظ...  17200000
# 23  گوشی موبایل شیائومی مدل Poco M5 ظرفیت 128GB رم...   5990000
# 24  گوشی موبایل شیائومی مدل Poco M5s دو سیم‌ کارت ...   7460000

# %%
df.to_csv('xiaomi_phones')

# %%
df.to_excel('xiaomi.xlsx', index=False)
